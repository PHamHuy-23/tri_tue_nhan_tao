# %% [markdown]
# # 🎨 Backtracking Search (Quay lui) - Tô màu bản đồ Úc
#
# Backtracking là thuật toán tìm kiếm theo chiều sâu được sử dụng phổ biến để giải quyết bài toán Thỏa mãn ràng buộc (CSP).
# Thuật toán gán giá trị cho từng biến một cách tuần tự, kiểm tra xem việc gán đó có vi phạm ràng buộc với các biến đã gán trước đó hay không. Nếu có vi phạm, thuật toán sẽ quay lui để thử giá trị khác.

# %% [markdown]
# ## 🛠️ 1. Khai báo Môi trường và Thiết lập

# %%
import sys
sys.path.append('../../Search_Algorithm')
from csp_solvers import backtracking_search, VARIABLES, NEIGHBORS

# %% [markdown]
# ## 🔍 2. Chạy thuật toán Backtracking

# %%
assignment, steps, backtracks = backtracking_search()

print("=== KẾT QUẢ BACKTRACKING SEARCH ===")
print(f"Kết quả gán màu: {assignment}")
print(f"Số bước gán (steps): {steps}")
print(f"Số lần quay lui (backtracks): {backtracks}")
