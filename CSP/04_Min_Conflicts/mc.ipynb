# %% [markdown]
# # 🎲 Min-Conflicts Search - Tô màu bản đồ Úc
#
# Min-Conflicts là thuật toán tìm kiếm cục bộ (Local Search) cực kỳ hiệu quả cho các bài toán CSP.
# Thuật toán bắt đầu bằng cách gán ngẫu nhiên giá trị cho tất cả các biến (dù có thể vi phạm ràng buộc). Tại mỗi bước lặp, nó chọn ngẫu nhiên một biến đang bị xung đột và gán lại giá trị gây ra **ít xung đột nhất** với các lân cận.

# %% [markdown]
# ## 🛠️ 1. Khai báo Môi trường và Thiết lập

# %%
import sys
sys.path.append('../../Search_Algorithm')
from csp_solvers import min_conflicts

# %% [markdown]
# ## 🔍 2. Chạy thuật toán Min-Conflicts

# %%
assignment, steps = min_conflicts(max_steps=1000)

print("=== KẾT QUẢ MIN-CONFLICTS SEARCH ===")
if assignment:
    print(f"Kết quả gán màu hoàn tất: {assignment}")
    print(f"Số bước lặp: {steps}")
else:
    print("Không tìm thấy lời giải trong số bước giới hạn.")
